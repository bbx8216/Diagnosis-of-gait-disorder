# %% [markdown]
# ### import

# %%
import module.feature_extract as feature
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### videos to keypoint

# %%
PATH = os.listdir("videos/")

# %%
PATH
# Out:
# ['Ataxic_Gait',
#  'Choreiform_Gait',
#  'Diplegic_Gait',
#  'Hemiplegic_Gait',
#  'Neuropathic_Gait',
#  'Normal_gait',
#  'Parkinsonian_Gait']

# %%
for path in PATH:       
    i = 0
    VIDEO_PATH = "videos/" + path +"/" 
    for video_file in os.listdir(VIDEO_PATH):
        dataframe = feature.extract_keypoint(path = VIDEO_PATH + video_file, 
                                        save_path = "dataset/"+ path + "/",
                                        show_video = False, save_file_name = str(i))
        i = i + 1
# Out:
# Done [videos/Ataxic_Gait/at_1_0.avi]
# Done [videos/Ataxic_Gait/at_1_1.avi]
# Done [videos/Ataxic_Gait/at_1_2.avi]
# Done [videos/Ataxic_Gait/at_1_3.avi]
# Done [videos/Ataxic_Gait/at_1_4.avi]
# Done [videos/Ataxic_Gait/at_1_5.avi]
# Done [videos/Ataxic_Gait/at_1_6.avi]
# Done [videos/Ataxic_Gait/at_1_7.avi]
# Done [videos/Ataxic_Gait/at_1_8.avi]
# Done [videos/Ataxic_Gait/at_1_9.avi]
# Done [videos/Ataxic_Gait/at_2_0.avi]
# Done [videos/Ataxic_Gait/at_2_1.avi]
# Done [videos/Ataxic_Gait/at_2_2.avi]
# Done [videos/Ataxic_Gait/at_2_3.avi]
# Done [videos/Ataxic_Gait/at_2_4.avi]
# Done [videos/Ataxic_Gait/at_2_5.avi]
# Done [videos/Ataxic_Gait/at_2_6.avi]
# Done [videos/Ataxic_Gait/at_2_7.avi]
# Done [videos/Ataxic_Gait/at_2_8.avi]
# Done [videos/Ataxic_Gait/at_2_9.avi]
# Done [videos/Ataxic_Gait/at_3.mp4]
# Done [videos/Ataxic_Gait/at_3_0.avi]
# Done [videos/Ataxic_Gait/at_3_1.avi]
# Done [videos/Ataxic_Gait/at_3_2.avi]
# Done [videos/Ataxic_Gait/at_3_3.avi]
# Done [videos/Ataxic_Gait/at_3_4.avi]
# Done [videos/Ataxic_Gait/at_3_5.avi]
# Done [videos/Ataxic_Gait/at_3_6.avi]
# Done [videos/Ataxic_Gait/at_3_7.avi]
# Done [videos/Ataxic_Gait/at_3_8.avi]
# Done [videos/Ataxic_Gait/at_3_9.avi]
# Done [videos/Ataxic_Gait/at_6.mp4]
# Done [videos/Ataxic_Gait/at_6_0.avi]
# Done [videos/Ataxic_Gait/at_6_1.avi]
# Done [videos/Ataxic_Gait/at_6_2.avi]
# Done [videos/Ataxic_Gait/at_6_3.avi]
# Done [videos/Ataxic_Gait/at_6_4.avi]
# Done [videos/Ataxic_Gait/at_6_5.avi]
# Done [videos/Ataxic_Gait/at_6_6.avi]
# Done [videos/Ataxic_Gait/at_6_7.avi]
# Done [videos/Ataxic_Gait/at_6_8.avi]
# Done [videos/Ataxic_Gait/at_6_9.avi]
# Done [videos/Ataxic_Gait/N_at_1.mp4]
# Done [videos/Parkinsonian_Gait/pk_7_0.avi]
# Done [videos/Parkinsonian_Gait/pk_7_1.avi]
# Done [videos/Parkinsonian_Gait/pk_7_2.avi]
# Done [videos/Parkinsonian_Gait/pk_7_3.avi]
# Done [videos/Parkinsonian_Gait/pk_7_4.avi]
# Done [videos/Parkinsonian_Gait/pk_7_5.avi]
# Done [videos/Parkinsonian_Gait/pk_7_6.avi]
# Done [videos/Parkinsonian_Gait/pk_7_7.avi]
# Done [videos/Parkinsonian_Gait/pk_7_8.avi]
# Done [videos/Parkinsonian_Gait/pk_7_9.avi]
# Done [videos/Parkinsonian_Gait/pk_8.mp4]
# Done [videos/Parkinsonian_Gait/pk_8_0.avi]
# Done [videos/Parkinsonian_Gait/pk_8_1.avi]
# Done [videos/Parkinsonian_Gait/pk_8_2.avi]
# Done [videos/Parkinsonian_Gait/pk_8_3.avi]
# Done [videos/Parkinsonian_Gait/pk_8_4.avi]
# Done [videos/Parkinsonian_Gait/pk_8_5.avi]
# Done [videos/Parkinsonian_Gait/pk_8_6.avi]
# Done [videos/Parkinsonian_Gait/pk_8_7.avi]
# Done [videos/Parkinsonian_Gait/pk_8_8.avi]
# Done [videos/Parkinsonian_Gait/pk_8_9.avi]
# Done [videos/Parkinsonian_Gait/pk_9.mp4]
# Done [videos/Parkinsonian_Gait/pk_9_0.avi]
# Done [videos/Parkinsonian_Gait/pk_9_1.avi]
# Done [videos/Parkinsonian_Gait/pk_9_2.avi]
# Done [videos/Parkinsonian_Gait/pk_9_3.avi]
# Done [videos/Parkinsonian_Gait/pk_9_4.avi]
# Done [videos/Parkinsonian_Gait/pk_9_5.avi]
# Done [videos/Parkinsonian_Gait/pk_9_6.avi]
# Done [videos/Parkinsonian_Gait/pk_9_7.avi]
# Done [videos/Parkinsonian_Gait/pk_9_8.avi]
# Done [videos/Parkinsonian_Gait/pk_9_9.avi]

# %% [markdown]
# ### load and save dataset

# %%
FILE_PATH = os.listdir("dataset/")

# %%
gait_class = FILE_PATH

# %%
result = pd.DataFrame()

# %%
gait_class
# Out:
# ['Ataxic_Gait',
#  'Choreiform_Gait',
#  'Diplegic_Gait',
#  'Hemiplegic_Gait',
#  'Neuropathic_Gait',
#  'Normal_gait',
#  'Parkinsonian_Gait']

# %%
i = 0
for path in gait_class:       
    CSV_PATH = "dataset/" + path +"/" 
    for dataset in os.listdir(CSV_PATH):
        dataframe = pd.read_csv(CSV_PATH + dataset)
        dataframe = feature.cut_dataframe(dataframe, drop = 0.1)
        dataframe["class"] = i
        result = pd.concat([result, dataframe])
    i = i + 1

# %%
result
# Out:
#        nose_x    nose_y    nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0    0.155794 -0.560939 -0.122072          0.147259         -0.604951
# 1    0.155777 -0.560795 -0.126155          0.147371         -0.604803
# 2    0.151617 -0.560695 -0.131444          0.144571         -0.604709
# 3    0.139049 -0.563633 -0.138267          0.132814         -0.607674
# 4    0.135167 -0.565018 -0.142545          0.129681         -0.609012
# ..        ...       ...       ...               ...               ...
# 182 -0.303948 -0.414238  0.197718         -0.331145         -0.426748
# 183 -0.302918 -0.414219  0.199615         -0.330161         -0.426677
# 184 -0.305781 -0.410886  0.186083         -0.335011         -0.422974
# 185 -0.314547 -0.415211  0.192501         -0.344674         -0.427505
# 186 -0.315678 -0.410134  0.185404         -0.346666         -0.420954
#
#      left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  left_eye_outer_x  \
# 0           -0.109733    0.147664   -0.605619   -0.108906          0.147330
# 1           -0.113815    0.147777   -0.605468   -0.112948          0.147425
# 2           -0.118378    0.144945   -0.605367   -0.117465          0.144515
# 3           -0.123936    0.133112   -0.608260   -0.122977          0.132613
# 4           -0.128080    0.129943   -0.609575   -0.127106          0.129434
# ..                ...         ...         ...         ...               ...
# 182          0.172025   -0.331310   -0.427586    0.172297         -0.331886
# 183          0.175729   -0.330323   -0.427509    0.176011         -0.330922
# 184          0.158206   -0.335119   -0.423660    0.158468         -0.335776
# 185          0.164881   -0.344763   -0.428099    0.165119         -0.345480
# 186          0.155283   -0.346733   -0.421482    0.155456         -0.347474
#
#      ...  right_heel_x  right_heel_y  right_heel_z  left_foot_index_x  \
# 0    ...      0.314534      0.748666     -0.287023           0.539134
# 1    ...      0.314017      0.752845     -0.278537           0.538825
# 2    ...      0.289041      0.758853     -0.270650           0.570117
# 3    ...      0.260245      0.770964     -0.265184           0.593108
# 4    ...      0.245045      0.778160     -0.279495           0.591652
# ..   ...           ...           ...           ...                ...
# 182  ...      0.319274      0.683392      0.210988           0.184620
# 183  ...      0.329461      0.684800      0.213763           0.169399
# 184  ...      0.344525      0.685570      0.216250           0.169070
# 185  ...      0.353283      0.685949      0.223411           0.151379
# 186  ...      0.358687      0.686486      0.238619           0.148565
#
#      left_foot_index_y  left_foot_index_z  right_foot_index_x  \
# 0             0.699718           0.286039            0.405057
# 1             0.699970           0.290130            0.401987
# 2             0.638595           0.365999            0.368249
# 3             0.595775           0.379040            0.336879
# 4             0.608952           0.379701            0.333814
# ..                 ...                ...                 ...
# 182           0.754611          -0.030712            0.313657
# 183           0.756781          -0.011788            0.319752
# 184           0.762877           0.013510            0.330500
# 185           0.767630           0.032031            0.337335
# 186           0.769362           0.056476            0.343932
#
#      right_foot_index_y  right_foot_index_z  class
# 0              0.742862           -0.425398      0
# 1              0.749201           -0.416365      0
# 2              0.757233           -0.410194      0
# 3              0.779245           -0.401995      0
# 4              0.788730           -0.416394      0
# ..                  ...                 ...    ...
# 182            0.757752            0.206457      6
# 183            0.753015            0.211183      6
# 184            0.746879            0.214495      6
# 185            0.734868            0.227470      6
# 186            0.730374            0.243289      6
#
# [126330 rows x 100 columns]

# %% [markdown]
# * 0 : 'Ataxic_Gait'
# * 1 :  'Choreiform_Gait'
# * 2 :  'Diplegic_Gait'
# * 3 :  'Hemiplegic_Gait'
# * 4 :  'Neuropathic_Gait'
# * 5 :  'Normal_gait'
# * 6 :  'Parkinsonian_Gait'

# %%
result["class"].value_counts()
# Out:
# 3    39788
# 6    39096
# 4    13867
# 2    11996
# 1    10418
# 0    10194
# 5      971
# Name: class, dtype: int64

# %%
result.to_csv("result/keypoints.csv", index = False)

# %%
result = pd.read_csv("result/keypoints.csv")

# %% [markdown]
# ### compute feature

# %%
feature_angle = feature.compute_angle_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_len = feature.compute_len_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_diff = feature.compute_diff_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
# Out:
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
feature_result = pd.concat([feature_angle, feature_diff, feature_len], axis = 1)

# %%
feature_result["class"] = result["class"]

# %%
feature_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126330 entries, 0 to 126329
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   left_hip_anlge        126320 non-null  float64
#  1   right_hip_anlge       126320 non-null  float64
#  2   left_knee_anlge       126320 non-null  float64
#  3   right_knee_anlge      126320 non-null  float64
#  4   left_ankle_angle_1    126320 non-null  float64
#  5   left_ankle_angle_2    126320 non-null  float64
#  6   right_ankle_angle_1   126320 non-null  float64
#  7   right_ankle_angle_2   126320 non-null  float64
#  8   hip_x_diff            126320 non-null  float64
#  9   hip_y_diff            126320 non-null  float64
#  10  hip_depth_diff        126320 non-null  float64
#  11  knee_x_diff           126320 non-null  float64
#  12  knee_y_diff           126320 non-null  float64
#  13  knee_depth_diff       126320 non-null  float64
#  14  ankle_x_diff          126320 non-null  float64
#  15  ankle_y_diff          126320 non-null  float64
#  16  ankle_depth_diff      126320 non-null  float64
#  17  heel_x_diff           126320 non-null  float64
#  18  heel_y_diff           126320 non-null  float64
#  19  heel_depth_diff       126320 non-null  float64
#  20  footindex_x_diff      126320 non-null  float64
#  21  footindex_y_diff      126320 non-null  float64
#  22  footindex_depth_diff  126320 non-null  float64
#  23  hip_length            126320 non-null  float64
#  24  knee_length           126320 non-null  float64
#  25  ankle_length          126320 non-null  float64
#  26  heel_length           126320 non-null  float64
#  27  footindex_length      126320 non-null  float64
#  28  class                 126330 non-null  int64
# dtypes: float64(28), int64(1)
# memory usage: 28.0 MB

# %%
feature_result.to_csv("result/features.csv", index = False)

# %% [markdown]
# ### EDA

# %%
#for eda
feature_angle = feature.compute_angle_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_angle["class"] = result["class"]
feature_len = feature.compute_len_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_len["class"] = result["class"]
feature_diff = feature.compute_diff_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_diff["class"] = result["class"]
# Out:
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# C:\Users\xodbs\anaconda3\envs\summer_cv\lib\site-packages\numpy\linalg\linalg.py:2159: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %% [markdown]
# ### EDA diff

# %% [markdown]
# ### EDA angle

# %% [markdown]
# ### EDA diff

# %%
feature_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126330 entries, 0 to 126329
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   hip_x_diff            126320 non-null  float64
#  1   hip_y_diff            126320 non-null  float64
#  2   hip_depth_diff        126320 non-null  float64
#  3   knee_x_diff           126320 non-null  float64
#  4   knee_y_diff           126320 non-null  float64
#  5   knee_depth_diff       126320 non-null  float64
#  6   ankle_x_diff          126320 non-null  float64
#  7   ankle_y_diff          126320 non-null  float64
#  8   ankle_depth_diff      126320 non-null  float64
#  9   heel_x_diff           126320 non-null  float64
#  10  heel_y_diff           126320 non-null  float64
#  11  heel_depth_diff       126320 non-null  float64
#  12  footindex_x_diff      126320 non-null  float64
#  13  footindex_y_diff      126320 non-null  float64
#  14  footindex_depth_diff  126320 non-null  float64
#  15  class                 126330 non-null  int64
# dtypes: float64(15), int64(1)
# memory usage: 15.4 MB

# %%
col_list = list(feature_diff.columns)
feature_name = ["hip", "knee", "ankle", "heel", "foot"]

for gait in range(len(gait_class)):
    feature_diff_by_class = feature_diff[feature_diff["class"] == gait]
    plt.figure(figsize = (20,20))
    plt.title(gait_class[gait])
    for i in range(int(len(col_list) / 3)):
        plt.scatter(x = feature_diff_by_class[col_list[i]], y=feature_diff_by_class[col_list[i+1]], label = feature_name[i])
    plt.legend()
    plt.show()

# %% [markdown]
# ## ML and KNN
# * 제대로 testing 한 것인지 모르겠음

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# %%
dataset = feature_result

# %%
dataset
# Out:
#        left_hip_anlge  right_hip_anlge  left_knee_anlge  right_knee_anlge  \
# 0          148.427729       150.930978      -168.393137       -168.690248
# 1          149.004593       151.639707      -168.831517       -169.054899
# 2          149.866687       154.455256      -176.729935       -169.385073
# 3          151.410257       157.807758       176.079346       -169.617673
# 4          151.174823       158.637350       178.446366       -169.004416
# ...               ...              ...              ...               ...
# 80471     -148.894821      -150.279451       145.814141        150.435330
# 80472     -148.853492      -151.532626       148.232962        151.565377
# 80473     -148.654625      -151.249430       148.151043        151.135993
# 80474     -147.980372      -150.832748       149.292862        151.125298
# 80475     -147.749140      -151.172486       155.561538        152.919724
#
#        left_ankle_angle_1  left_ankle_angle_2  right_ankle_angle_1  \
# 0              134.300391          134.300391           131.807541
# 1              134.225455          134.225455           133.502207
# 2              135.144423          135.144423           134.610390
# 3              136.121906          136.121906           138.617568
# 4              134.825773          134.825773           135.521153
# ...                   ...                 ...                  ...
# 80471         -104.341687         -104.341687          -108.568118
# 80472          -96.459851          -96.459851          -106.551255
# 80473          -95.031805          -95.031805          -106.884871
# 80474          -95.232281          -95.232281          -107.607367
# 80475         -100.503823         -100.503823          -106.234848
#
#        right_ankle_angle_2  hip_x_diff  hip_y_diff  ...  heel_depth_diff  \
# 0               178.505128   -0.154935    0.039753  ...        -0.623382
# 1               178.704709   -0.157103    0.040176  ...        -0.620717
# 2               177.797498   -0.160072    0.041390  ...        -0.679714
# 3               176.920373   -0.164717    0.043902  ...        -0.684294
# 4               175.881984   -0.165472    0.045260  ...        -0.697298
# ...                    ...         ...         ...  ...              ...
# 80471          -165.734123   -0.018784    0.023998  ...         0.224150
# 80472          -164.872788   -0.018362    0.022882  ...         0.265892
# 80473          -164.931655   -0.017985    0.022187  ...         0.275203
# 80474          -165.090724   -0.017068    0.021451  ...         0.276396
# 80475          -166.924185   -0.017099    0.021730  ...         0.271984
#
#        footindex_x_diff  footindex_y_diff  footindex_depth_diff  hip_length  \
# 0             -0.134077          0.043144             -0.711437    0.159954
# 1             -0.136838          0.049231             -0.706496    0.162159
# 2             -0.201867          0.118639             -0.776193    0.165336
# 3             -0.256229          0.183470             -0.781036    0.170467
# 4             -0.257838          0.179778             -0.796095    0.171550
# ...                 ...               ...                   ...         ...
# 80471         -0.035877          0.043248              0.238066    0.030476
# 80472         -0.010272          0.032911              0.287948    0.029339
# 80473         -0.000888          0.034259              0.300278    0.028561
# 80474          0.014484          0.030063              0.301999    0.027412
# 80475          0.037625          0.015192              0.299361    0.027651
#
#        knee_length  ankle_length  heel_length  footindex_length  class
# 0         0.132421      0.116557     0.121203          0.140848      0
# 1         0.133666      0.118970     0.123811          0.145425      0
# 2         0.146326      0.189679     0.202942          0.234148      0
# 3         0.159791      0.251833     0.271701          0.315142      0
# 4         0.168795      0.257558     0.275549          0.314325      0
# ...            ...           ...          ...               ...    ...
# 80471     0.023497      0.029536     0.042218          0.056193      5
# 80472     0.015930      0.012968     0.021610          0.034477      5
# 80473     0.016620      0.010439     0.019485          0.034271      5
# 80474     0.014531      0.004161     0.005988          0.033371      5
# 80475     0.012301      0.039153     0.036471          0.040576      5
#
# [80476 rows x 29 columns]

# %%
#X = (dataset.iloc[:, :-1] - dataset.iloc[:, :-1].mean()) / dataset.iloc[:, :-1].std()

# %%
X = dataset.iloc[:, :-1].to_numpy()

# %%
Y = dataset.iloc[:, 28].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(len(X_train), len(X_test))
print(X_train[:3])
print(y_train[:3])

# %%
scaler = StandardScaler() # Scaler 객체 생성
scaler.fit(X_train) # 스케일링(표준화)를 위한 평균과 표준 편차 계산
X_train = scaler.transform(X_train) # 스케일링(표준화 수행)
X_test = scaler.transform(X_test)

# %%
for col in range(4):
    print(f'평균 = {X_train[:, col].mean()}, 표준편차= {X_train[:, col].std()}')
for col in range(4):
    print(f'평균 = {X_test[:, col].mean()}, 표준편차= {X_test[:, col].std()}')

# %%
# k-NN 분류기를 생성
classifier = KNeighborsClassifier(n_neighbors=5)
# 분류기 학습
classifier.fit(X_train, y_train)
# 예측
y_pred = classifier.predict(X_test)
print(y_pred)
# 5. 모델 평가
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
print(classification_report(y_test, y_pred))
report = classification_report(y_test, y_pred, output_dict=True)

# %%
report["accuracy"]

# %%
errors = []
acc = []
for i in range(1, 31):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    errors.append(np.mean(pred_i != y_test))
    report = classification_report(y_test, y_pred, output_dict=True)
    acc.append(report["accuracy"])

#print(errors)

plt.plot(range(1, 31), errors, marker='o')
plt.title('Mean error with K-Value')
plt.xlabel('k-value')
plt.ylabel('mean error')
plt.show()

plt.plot(range(1, 31), acc, color = 'violet', marker='o')
plt.title('Acc with K-Value')
plt.xlabel('k-value')
plt.ylabel('acc')
plt.show()

# %%
print(acc)
