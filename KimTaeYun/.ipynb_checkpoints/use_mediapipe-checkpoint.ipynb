# %%
import mediapipe as mp
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from mpl_toolkits.mplot3d import Axes3D

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
landmark_names = [
        'nose',
        'left_eye_inner',
        'left_eye',
        'left_eye_outer',
        'right_eye_inner',
        'right_eye',
        'right_eye_outer',
        'left_ear',
        'right_ear',
        'mouth_left',
        'mouth_right',
        'left_shoulder',
        'right_shoulder',
        'left_elbow',
        'right_elbow',
        'left_wrist', 'right_wrist',
        'left_pinky_1', 'right_pinky_1',
        'left_index_1', 'right_index_1',
        'left_thumb_2', 'right_thumb_2',
        'left_hip', 'right_hip',
        'left_knee', 'right_knee',
        'left_ankle', 'right_ankle',
        'left_heel', 'right_heel',
        'left_foot_index', 'right_foot_index',
    ]
landmark_list = []
for i in landmark_names:
    for j in ["_x", "_y", "_z"]:
        landmark_list.append(i + j)

# %%
results_points = []
cap = cv2.VideoCapture("walk_side.mp4")
with mp_pose.Pose(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            # print("카메라를 찾을 수 없습니다.")
            # 동영상을 불러올 경우는 'continue' 대신 'break'를 사용합니다.
            break

        # 필요에 따라 성능 향상을 위해 이미지 작성을 불가능함으로 기본 설정합니다.
        image.flags.writeable = False
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        points = []
        for i in range(len(landmark_names)):
            points.append(results.pose_world_landmarks.landmark[i].x)
            points.append(results.pose_world_landmarks.landmark[i].y)
            points.append(results.pose_world_landmarks.landmark[i].z)
        results_points.append(points)
        #print(results.pose_landmarks)
        #mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

        # 포즈 주석을 이미지 위에 그립니다.
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())
        # 보기 편하게 이미지를 좌우 반전합니다.
        cv2.imshow('MediaPipe Pose', cv2.flip(image, 1))
        if cv2.waitKey(5) & 0xFF == 27:
            break
cv2.destroyAllWindows
cap.release()

# %% [markdown]
# normalize 된 듯?
#
#
# 최대한 비슷하게 나오려면...
#
#
# 사람 나온 곳을 crop해서 사용하면 될 것 같긴 하다.

# %%
mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

# %%
point_dataframe = pd.DataFrame(columns = landmark_list, data = results_points)

# %%
point_dataframe
# Out:
#        nose_x    nose_y    nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0    0.189573 -0.597068 -0.163225          0.164992         -0.641987
# 1    0.193588 -0.603334 -0.149474          0.167534         -0.646749
# 2    0.211302 -0.615537 -0.139884          0.186049         -0.658645
# 3    0.217025 -0.623345 -0.139500          0.192396         -0.666512
# 4    0.217587 -0.621558 -0.133263          0.193579         -0.664917
# ..        ...       ...       ...               ...               ...
# 134  0.172675 -0.603860 -0.098230          0.157629         -0.645690
# 135  0.172800 -0.604111 -0.100596          0.157548         -0.645890
# 136  0.172851 -0.603654 -0.103807          0.157453         -0.645369
# 137  0.172274 -0.601551 -0.108398          0.156698         -0.643332
# 138  0.172375 -0.599843 -0.110666          0.156682         -0.641646
#
#      left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  left_eye_outer_x  \
# 0           -0.153325    0.165396   -0.642102   -0.152595          0.165288
# 1           -0.137942    0.167917   -0.646882   -0.137253          0.167712
# 2           -0.128379    0.186389   -0.658804   -0.127688          0.186094
# 3           -0.128613    0.192676   -0.666626   -0.127903          0.192430
# 4           -0.123402    0.193843   -0.665022   -0.122657          0.193650
# ..                ...         ...         ...         ...               ...
# 134         -0.085949    0.157888   -0.645668   -0.085247          0.157707
# 135         -0.088546    0.157805   -0.645877   -0.087849          0.157620
# 136         -0.092017    0.157710   -0.645374   -0.091318          0.157522
# 137         -0.096937    0.156964   -0.643359   -0.096241          0.156786
# 138         -0.099078    0.156951   -0.641688   -0.098388          0.156774
#
#      ...  left_heel_z  right_heel_x  right_heel_y  right_heel_z  \
# 0    ...     0.219943     -0.074937      0.806014      0.040866
# 1    ...     0.205442     -0.085021      0.802507      0.035435
# 2    ...     0.213280     -0.098092      0.792451      0.047457
# 3    ...     0.213796     -0.129218      0.782278      0.070536
# 4    ...     0.213007     -0.149983      0.771653      0.102458
# ..   ...          ...           ...           ...           ...
# 134  ...     0.252255     -0.020252      0.797077      0.084293
# 135  ...     0.253856     -0.019843      0.797681      0.083454
# 136  ...     0.252636     -0.020226      0.800890      0.083016
# 137  ...     0.249989     -0.020457      0.802043      0.076922
# 138  ...     0.245136     -0.020192      0.805493      0.065324
#
#      left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0             0.054205           0.828724           0.167491
# 1             0.042096           0.823012           0.151791
# 2             0.034728           0.805992           0.166923
# 3             0.084782           0.796275           0.167291
# 4             0.119917           0.781949           0.166544
# ..                 ...                ...                ...
# 134           0.047086           0.842310           0.200128
# 135           0.046662           0.837415           0.203124
# 136           0.044516           0.837369           0.202032
# 137           0.044526           0.836991           0.199022
# 138           0.044384           0.837431           0.193021
#
#      right_foot_index_x  right_foot_index_y  right_foot_index_z
# 0              0.042717            0.835529           -0.055435
# 1              0.023676            0.831995           -0.059656
# 2              0.011385            0.824457           -0.049063
# 3             -0.022285            0.816900           -0.034294
# 4             -0.048812            0.805134            0.001875
# ..                  ...                 ...                 ...
# 134            0.080760            0.829856            0.010952
# 135            0.081989            0.829422            0.009869
# 136            0.082571            0.832004            0.007272
# 137            0.083109            0.832080           -0.003527
# 138            0.082975            0.833669           -0.017390
#
# [139 rows x 99 columns]

# %%
point_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 99 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nose_x              139 non-null    float64
#  1   nose_y              139 non-null    float64
#  2   nose_z              139 non-null    float64
#  3   left_eye_inner_x    139 non-null    float64
#  4   left_eye_inner_y    139 non-null    float64
#  5   left_eye_inner_z    139 non-null    float64
#  6   left_eye_x          139 non-null    float64
#  7   left_eye_y          139 non-null    float64
#  8   left_eye_z          139 non-null    float64
#  9   left_eye_outer_x    139 non-null    float64
#  10  left_eye_outer_y    139 non-null    float64
#  11  left_eye_outer_z    139 non-null    float64
#  12  right_eye_inner_x   139 non-null    float64
#  13  right_eye_inner_y   139 non-null    float64
#  14  right_eye_inner_z   139 non-null    float64
#  15  right_eye_x         139 non-null    float64
#  16  right_eye_y         139 non-null    float64
#  17  right_eye_z         139 non-null    float64
#  18  right_eye_outer_x   139 non-null    float64
#  19  right_eye_outer_y   139 non-null    float64
#  20  right_eye_outer_z   139 non-null    float64
#  21  left_ear_x          139 non-null    float64
#  22  left_ear_y          139 non-null    float64
#  23  left_ear_z          139 non-null    float64
#  24  right_ear_x         139 non-null    float64
#  25  right_ear_y         139 non-null    float64
#  26  right_ear_z         139 non-null    float64
#  27  mouth_left_x        139 non-null    float64
#  28  mouth_left_y        139 non-null    float64
#  29  mouth_left_z        139 non-null    float64
#  30  mouth_right_x       139 non-null    float64
#  31  mouth_right_y       139 non-null    float64
#  32  mouth_right_z       139 non-null    float64
#  33  left_shoulder_x     139 non-null    float64
#  34  left_shoulder_y     139 non-null    float64
#  35  left_shoulder_z     139 non-null    float64
#  36  right_shoulder_x    139 non-null    float64
#  37  right_shoulder_y    139 non-null    float64
#  38  right_shoulder_z    139 non-null    float64
#  39  left_elbow_x        139 non-null    float64
#  40  left_elbow_y        139 non-null    float64
#  41  left_elbow_z        139 non-null    float64
#  42  right_elbow_x       139 non-null    float64
#  43  right_elbow_y       139 non-null    float64
#  44  right_elbow_z       139 non-null    float64
#  45  left_wrist_x        139 non-null    float64
#  46  left_wrist_y        139 non-null    float64
#  47  left_wrist_z        139 non-null    float64
#  48  right_wrist_x       139 non-null    float64
#  49  right_wrist_y       139 non-null    float64
#  50  right_wrist_z       139 non-null    float64
#  51  left_pinky_1_x      139 non-null    float64
#  52  left_pinky_1_y      139 non-null    float64
#  53  left_pinky_1_z      139 non-null    float64
#  54  right_pinky_1_x     139 non-null    float64
#  55  right_pinky_1_y     139 non-null    float64
#  56  right_pinky_1_z     139 non-null    float64
#  57  left_index_1_x      139 non-null    float64
#  58  left_index_1_y      139 non-null    float64
#  59  left_index_1_z      139 non-null    float64
#  60  right_index_1_x     139 non-null    float64
#  61  right_index_1_y     139 non-null    float64
#  62  right_index_1_z     139 non-null    float64
#  63  left_thumb_2_x      139 non-null    float64
#  64  left_thumb_2_y      139 non-null    float64
#  65  left_thumb_2_z      139 non-null    float64
#  66  right_thumb_2_x     139 non-null    float64
#  67  right_thumb_2_y     139 non-null    float64
#  68  right_thumb_2_z     139 non-null    float64
#  69  left_hip_x          139 non-null    float64
#  70  left_hip_y          139 non-null    float64
#  71  left_hip_z          139 non-null    float64
#  72  right_hip_x         139 non-null    float64
#  73  right_hip_y         139 non-null    float64
#  74  right_hip_z         139 non-null    float64
#  75  left_knee_x         139 non-null    float64
#  76  left_knee_y         139 non-null    float64
#  77  left_knee_z         139 non-null    float64
#  78  right_knee_x        139 non-null    float64
#  79  right_knee_y        139 non-null    float64
#  80  right_knee_z        139 non-null    float64
#  81  left_ankle_x        139 non-null    float64
#  82  left_ankle_y        139 non-null    float64
#  83  left_ankle_z        139 non-null    float64
#  84  right_ankle_x       139 non-null    float64
#  85  right_ankle_y       139 non-null    float64
#  86  right_ankle_z       139 non-null    float64
#  87  left_heel_x         139 non-null    float64
#  88  left_heel_y         139 non-null    float64
#  89  left_heel_z         139 non-null    float64
#  90  right_heel_x        139 non-null    float64
#  91  right_heel_y        139 non-null    float64
#  92  right_heel_z        139 non-null    float64
#  93  left_foot_index_x   139 non-null    float64
#  94  left_foot_index_y   139 non-null    float64
#  95  left_foot_index_z   139 non-null    float64
#  96  right_foot_index_x  139 non-null    float64
#  97  right_foot_index_y  139 non-null    float64
#  98  right_foot_index_z  139 non-null    float64
# dtypes: float64(99)
# memory usage: 107.6 KB

# %%
for i in range(len(landmark_names)):
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    plt.title(landmark_names[i] + " : " + str(i))
    x = point_dataframe[landmark_list[i*3]]
    y = point_dataframe[landmark_list[i*3+1]]
    z = point_dataframe[landmark_list[i*3+2]]
    ax.plot(x,y,z)
# Out:
# <ipython-input-92-0e5c2e4cf5de>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
